# %% [markdown]
# # Python для анализа данных
#
# ## Введение в Pandas
#
# Pandas - библиотека для работы с табличными данными в питоне.
# * Документация: https://pandas.pydata.org/
# * 10 minutes intro: https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#min
# * Pandas Cheat-Sheet: https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %%
import pandas as pd # импортировали библиотеку pandas и назвали ее pd

# %%
data = pd.read_csv('train.csv')

# %% [markdown]
# Функция read_csv читает данные из файла формата csv данные и преобразует в pandas.DataFrame. Аналогичная функция read_excel может читать данные в офрмате xls(x).
#
# Посмотрим на наши данные:

# %%
data.head(10) # функция head() показывает первые строки датафрейма, по умолчанию 5
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            3         1       3
# 4            4         1       1
# 5            5         0       3
# 6            6         0       3
# 7            7         0       1
# 8            8         0       3
# 9            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3                             Heikkinen, Miss. Laina  female  26.0      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                           Allen, Mr. William Henry    male  35.0      0
# 6                                   Moran, Mr. James    male   NaN      0
# 7                            McCarthy, Mr. Timothy J    male  54.0      0
# 8                     Palsson, Master. Gosta Leonard    male   2.0      3
# 9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0  STON/O2. 3101282   7.9250   NaN        S
# 4      0            113803  53.1000  C123        S
# 5      0            373450   8.0500   NaN        S
# 6      0            330877   8.4583   NaN        Q
# 7      0             17463  51.8625   E46        S
# 8      1            349909  21.0750   NaN        S
# 9      2            347742  11.1333   NaN        S

# %%
data.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %%
data.shape # функция shape показывает размерность датафрейма (строк, столбцов)
# Out:
# (891, 12)

# %%
data.columns # список столбцов
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Описание признаков из [источника данных](https://www.kaggle.com/competitions/titanic/data):
#
# **PassengerId** - id пассажира
#
# **Survived** бинарная переменная: выжил пассажирил (1) или нет (0)
#
# **Pclass** - класс пассажира
#
# **Name** - имя пассажира
#
# **Sex** - пол пассажира
#
# **Age** - возраст пассажира
#
# **SibSp** - количество родственников (братьев, сестер, супругов) пассажира на борту
#
# **Parch** - количество родственников (родителей / детей) пассажира на борту
#
# **Ticket** - номер билета
#
# **Fare** - тариф (стоимость билета)
#
# **Cabin** - номер кабины
#
# **Embarked** - порт, в котором пассажир сел на борт (C - Cherbourg, S - Southampton, Q = Queenstown)

# %% [markdown]
# Так можно обратиться к столбцу:

# %%
data['Age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
data.Age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
data.age
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 data.age
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %% [markdown]
# Или к нескольким столбцам сразу:

# %%
data[['Age', 'Sex']].head()
# Out:
#    Age  Sex
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN

# %% [markdown]
# A так - к строке по индексу:
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html

# %%
data.loc[3, ['Name', 'Age', 'Survived']]
# Out:
# Name        NaN
# Age         NaN
# Survived    NaN
# Name: 3, dtype: object

# %%
data.iloc[3, 3:5]
# Out:
# Name    NaN
# Sex     NaN
# Name: 3, dtype: object

# %%
data.loc[0]
# Out:
# PassengerId    1,0,3,"Braund, Mr. Owen Harris",male,22,1,0,A/...
# Survived                                                     NaN
# Pclass                                                       NaN
# Name                                                         NaN
# Sex                                                          NaN
# Age                                                          NaN
# SibSp                                                        NaN
# Parch                                                        NaN
# Ticket                                                       NaN
# Fare                                                         NaN
# Cabin                                                        NaN
# Embarked                                                     NaN
# Name: 0, dtype: object

# %%
data.iloc[0]

# %%
data.iloc[1:3] # строки с 1 по 3

# %%
data.dtypes
# object - имеется в виду строчной тип данных
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe()

data.describe().applymap('{:,.2f}'.format) # чтобы сделать форматирование читабельнее
# в расчете пропущенные ячейки не учитываются
# Out:
#       PassengerId Survived  Pclass     Age   SibSp   Parch    Fare
# count      891.00   891.00  891.00  714.00  891.00  891.00  891.00
# mean       446.00     0.38    2.31   29.70    0.52    0.38   32.20
# std        257.35     0.49    0.84   14.53    1.10    0.81   49.69
# min          1.00     0.00    1.00    0.42    0.00    0.00    0.00
# 25%        223.50     0.00    2.00   20.12    0.00    0.00    7.91
# 50%        446.00     0.00    3.00   28.00    0.00    0.00   14.45
# 75%        668.50     1.00    3.00   38.00    1.00    0.00   31.00
# max        891.00     1.00    3.00   80.00    8.00    6.00  512.33

# %%
data[['Age', 'Fare', 'Survived']].describe() # также можно применять только к отдельным колонкам

# %% [markdown]
# Статистики:
#
# * count - количество непустых значений
# * mean - среднее значение
# * std - стандартное отклонение – мера разброса в наборе числовых данных. Выражаясь простыми словами, насколько далеко от среднего арифметического (mean) находятся точки данных. Чем выше значение стандартного отклонения, тем более разбросаны значения в выборке. И наоборот, чем ниже значение стандартного отклонения, тем более плотно упакованы значения.
# * min - минимальное значение
# * 25% - 25% перцентиль
# * 50% - 50% перцентиль
# * 75% - 75% перцентиль
# * max - максимальное значение
#
# Подробнее про квантили и перцентили: https://vk.com/@hsotalks-zachem-yaschiku-usy-kvartili-raspredeleniya

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.describe(include=['object'])
# Out:
#                           Name   Sex Ticket    Cabin Embarked
# count                      892   892    892      204      890
# unique                     891     2    681      147        3
# top     Heikkinen, Miss. Laina  male   1601  B96 B98        S
# freq                         2   577      7        4      645

# %%
data['Age'].min()
# Out:
# 0.42

# %%
data['Age'].max()
# Out:
# 80.0

# %%
data['Age'].median()
# Out:
# 28.0

# %%
data['Age'].quantile(0.9)
# Out:
# 50.0

# %%
data['Age'].mean()
# Out:
# 29.693944055944055

# %%
data['Age'] > data['Age'].mean()
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891     True
# Name: Age, Length: 892, dtype: bool

# %%
data[data['Age'] > data['Age'].mean()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 4              4         1       1
# 5              5         0       3
# 7              7         0       1
# 12            12         1       1
# ..           ...       ...     ...
# 874          874         0       3
# 880          880         1       1
# 882          882         0       3
# 886          886         0       3
# 891          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                             Allen, Mr. William Henry    male  35.0      0
# 7                              McCarthy, Mr. Timothy J    male  54.0      0
# 12                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 874                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 882                                 Markun, Mr. Johann    male  33.0      0
# 886               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 891                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 4        0    113803  53.1000  C123        S
# 5        0    373450   8.0500   NaN        S
# 7        0     17463  51.8625   E46        S
# 12       0    113783  26.5500  C103        S
# ..     ...       ...      ...   ...      ...
# 874      0    345765   9.0000   NaN        S
# 880      1     11767  83.1583   C50        C
# 882      0    349257   7.8958   NaN        S
# 886      5    382652  29.1250   NaN        Q
# 891      0    370376   7.7500   NaN        Q
#
# [330 rows x 12 columns]

# %%
data[data['Age'] > data['Age'].mean()]['Name'].head(10)
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 4          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                              Allen, Mr. William Henry
# 7                               McCarthy, Mr. Timothy J
# 12                             Bonnell, Miss. Elizabeth
# 14                          Andersson, Mr. Anders Johan
# 16                     Hewlett, Mrs. (Mary D Kingcome)
# 19    Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 21                                 Fynney, Mr. Joseph J
# 22                                Beesley, Mr. Lawrence
# Name: Name, dtype: object

# %%
data[(data['Age'] > data['Age'].mean()) & (data['Pclass'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 4              4         1       1
# 7              7         0       1
# 12            12         1       1
# 31            31         0       1
# ..           ...       ...     ...
# 863          863         1       1
# 868          868         0       1
# 872          872         1       1
# 873          873         0       1
# 880          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                              McCarthy, Mr. Timothy J    male  54.0      0
# 12                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# 863  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 868               Roebling, Mr. Washington Augustus II    male  31.0      0
# 872   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 873                           Carlsson, Mr. Frans Olof    male  33.0      0
# 880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 4        0    113803  53.1000         C123        S
# 7        0     17463  51.8625          E46        S
# 12       0    113783  26.5500         C103        S
# 31       0  PC 17601  27.7208          NaN        C
# ..     ...       ...      ...          ...      ...
# 863      0     17466  25.9292          D17        S
# 868      0  PC 17590  50.4958          A24        S
# 872      1     11751  52.5542          D35        S
# 873      0       695   5.0000  B51 B53 B55        S
# 880      1     11767  83.1583          C50        C
#
# [131 rows x 12 columns]

# %%
data[data['Fare'] > 200] #.shape[0]

# %%
q = (data['Age'] > data['Age'].mean()) & (data['Pclass'] == 1) & \
    (data['Sex'] == 'female')

# %%
data[q].shape
# 55- кол-во строк, 12 - кол-во колонок
# Out:
# (55, 12)

# %%
data[q]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 4              4         1       1
# 12            12         1       1
# 53            53         1       1
# 62            62         1       1
# 178          178         0       1
# 195          195         1       1
# 196          196         1       1
# 216          216         1       1
# 219          219         1       1
# 231          231         1       1
# 258          258         1       1
# 259          259         1       1
# 269          269         1       1
# 270          270         1       1
# 276          276         1       1
# 300          300         1       1
# 310          310         1       1
# 319          319         1       1
# 320          320         1       1
# 326          326         1       1
# 338          338         1       1
# 367          367         1       1
# 381          381         1       1
# 384          384         1       1
# 413          413         1       1
# 487          487         1       1
# 497          497         1       1
# 514          514         1       1
# 521          521         1       1
# 524          524         1       1
# 538          538         1       1
# 541          541         1       1
# 557          557         1       1
# 559          559         1       1
# 572          572         1       1
# 578          578         1       1
# 582          582         1       1
# 592          592         1       1
# 610          610         1       1
# 717          717         1       1
# 760          760         1       1
# 764          764         1       1
# 766          766         1       1
# 780          780         1       1
# 797          797         1       1
# 810          810         1       1
# 821          821         1       1
# 830          830         1       1
# 836          836         1       1
# 843          843         1       1
# 857          857         1       1
# 863          863         1       1
# 872          872         1       1
# 880          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 12                            Bonnell, Miss. Elizabeth  female  58.0      0
# 53            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 62                                 Icard, Miss. Amelie  female  38.0      0
# 178                         Isham, Miss. Ann Elizabeth  female  50.0      0
# 195          Brown, Mrs. James Joseph (Margaret Tobin)  female  44.0      0
# 196                               Lurette, Miss. Elise  female  58.0      0
# 216                            Newell, Miss. Madeleine  female  31.0      1
# 219                              Bazzani, Miss. Albina  female  32.0      0
# 231       Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0      1
# 258                               Cherry, Miss. Gladys  female  30.0      0
# 259                                   Ward, Miss. Anna  female  35.0      0
# 269      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 270                             Bissette, Miss. Amelia  female  35.0      0
# 276                  Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 300    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 310                     Francatelli, Miss. Laura Mabel  female  30.0      0
# 319                           Wick, Miss. Mary Natalie  female  31.0      0
# 320  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0      1
# 326                           Young, Miss. Marie Grice  female  36.0      0
# 338                    Burns, Miss. Elizabeth Margaret  female  41.0      0
# 367   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 381                              Bidois, Miss. Rosalie  female  42.0      0
# 384  Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.0      1
# 413                             Minahan, Miss. Daisy E  female  33.0      1
# 487    Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  35.0      1
# 497                     Eustis, Miss. Elizabeth Mussey  female  54.0      1
# 514     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 521                              Perreault, Miss. Anne  female  30.0      0
# 524    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female  44.0      0
# 538                                LeRoy, Miss. Bertha  female  30.0      0
# 541                            Crosby, Miss. Harriet R  female  36.0      0
# 557  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
# 559             Taussig, Mrs. Emil (Tillie Mandelbaum)  female  39.0      1
# 572      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0      2
# 578          Silvey, Mrs. William Baird (Alice Munger)  female  39.0      1
# 582  Thayer, Mrs. John Borland (Marian Longstreth M...  female  39.0      1
# 592    Stephenson, Mrs. Walter Bertram (Martha Eustis)  female  52.0      1
# 610                          Shutes, Miss. Elizabeth W  female  40.0      0
# 717                      Endres, Miss. Caroline Louise  female  38.0      0
# 760  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 764          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 766               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1
# 780  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 797                        Leader, Dr. Alice (Farnham)  female  49.0      0
# 810     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
# 821  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 830          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 836                        Compton, Miss. Sara Rebecca  female  39.0      1
# 843                            Serepeca, Miss. Augusta  female  30.0      0
# 857         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 863  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 872   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch     Ticket      Fare    Cabin Embarked
# 1        0   PC 17599   71.2833      C85        C
# 4        0     113803   53.1000     C123        S
# 12       0     113783   26.5500     C103        S
# 53       0   PC 17572   76.7292      D33        C
# 62       0     113572   80.0000      B28      NaN
# 178      0   PC 17595   28.7125      C49        C
# 195      0   PC 17610   27.7208       B4        C
# 196      0   PC 17569  146.5208      B80        C
# 216      0      35273  113.2750      D36        C
# 219      0      11813   76.2917      D15        C
# 231      0      36973   83.4750      C83        S
# 258      0     110152   86.5000      B77        S
# 259      0   PC 17755  512.3292      NaN        C
# 269      1   PC 17582  153.4625     C125        S
# 270      0   PC 17760  135.6333      C99        S
# 276      0      13502   77.9583       D7        S
# 300      1   PC 17558  247.5208  B58 B60        C
# 310      0   PC 17485   56.9292      E36        C
# 319      2      36928  164.8667       C7        S
# 320      1      16966  134.5000      E34        C
# 326      0   PC 17760  135.6333      C32        C
# 338      0      16966  134.5000      E40        C
# 367      0     110813   75.2500      D37        C
# 381      0   PC 17757  227.5250      NaN        C
# 384      0     113789   52.0000      NaN        S
# 413      0      19928   90.0000      C78        Q
# 487      0      19943   90.0000      C93        S
# 497      0      36947   78.2667      D20        C
# 514      0   PC 17603   59.4000      NaN        C
# 521      0      12749   93.5000      B73        S
# 524      1     111361   57.9792      B18        C
# 538      0   PC 17761  106.4250      NaN        C
# 541      2  WE/P 5735   71.0000      B22        S
# 557      0      11755   39.6000      A16        C
# 559      1     110413   79.6500      E67        S
# 572      0      11769   51.4792     C101        S
# 578      0      13507   55.9000      E44        S
# 582      1      17421  110.8833      C68        C
# 592      0      36947   78.2667      D20        C
# 610      0   PC 17582  153.4625     C125        S
# 717      0   PC 17757  227.5250      C45        C
# 760      0     110152   86.5000      B77        S
# 764      2     113760  120.0000  B96 B98        S
# 766      0      13502   77.9583      D11        S
# 780      1      24160  211.3375       B3        S
# 797      0      17465   25.9292      D17        S
# 810      0     113806   53.1000       E8        S
# 821      1      12749   93.5000      B69        S
# 830      0     113572   80.0000      B28      NaN
# 836      1   PC 17756   83.1583      E49        C
# 843      0     113798   31.0000      NaN        C
# 857      1      36928  164.8667      NaN        S
# 863      0      17466   25.9292      D17        S
# 872      1      11751   52.5542      D35        S
# 880      1      11767   83.1583      C50        C

# %%
data[(data['Sex'] == 'female') | ((data['Pclass'] == 1))]

# %%
data[data['PassengerId'] == 2][['Name','Pclass']]
# Out:
#                                                 Name  Pclass
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1

# %%
loc работает с индексами(которые могут быть слова)
iloc работает с относительными индексами, т.е. только циферки от 0 ..

# %%
data.loc[1:3, 'Survived':'Sex'] # строки с 1 по 3, колонки от Survived до Sex

# %%
data.iloc[1:3, 1:5]

# %% [markdown]
# Кроме того, можно выбирать объекты, удовлетворяющие каким-то свойствам, например, все пассажиры-женщины:

# %%
data[data.Sex == 'female'].head()

# %% [markdown]
# Пассажиры первого класса:

# %%
data[(data.Pclass == 1) & (data.Sex == 'female')].shape

# %% [markdown]
# Пассажиры первого или второго классов: # (равно предыдущему выражению)

# %%
data[data.Pclass.isin([1,2])].head()

# %%
data.Pclass.isin([1, 2])

# %% [markdown]
# Пассажиры младше 18:

# %%
data[data.Age < 18].shape

# %% [markdown]
# Девушки в возрасте от 18 до 25, путешествующие в одиночку (без каких-либо родственников):

# %%
data[(data.Sex == 'female') & (data.Age > 18) & (
    data.Age < 25) & (data.SibSp == 0) & (data.Parch == 0)]

# %% [markdown]
# Сколько таких путешественниц?

# %%
data[(data.Sex == 'female') & (data.Age > 18) & (data.Age < 25)
     & (data.SibSp == 0) & (data.Parch == 0) & (data.Survived == 0)].shape[0]

# %% [markdown]
# <hr>

# %% [markdown]
# ### Задачи
#
# 1) Посчитайте количество пассажиров первого класса, которые сели на борт в Саутгемптоне.

# %%
data

# %%
# TODO
data[(data['Pclass'] == 1) & (data['Embarked'] == 'S')].shape[0]

# %% [markdown]
# 2) Сколько пассажиров третьего класса, которые путешествовали в компании 2 или более родственников?

# %%
# TODO
data[(data['Pclass'] == 3) & (data['SibSp'] + data['Parch'] >= 2) ] #.shape

# %% [markdown]
# 3) Сколько в среднем стоил билет первого класса?

# %%
# TODO
round(data[(data['Pclass'] == 1)]['Fare'].mean(), 2)

# %% [markdown]
# <hr>

# %% [markdown]
# Иногда нужно создать новый признак из уже существующих, например, нам интересно, сколько всего родственников путешествовало с каждым пассажиром - просто сложим столбцы SibSp и Parch и поместим сумму в новый столбец FamilySize. Такая процедура называет broadcasting.

# %%
data['FamilySize'] = data['SibSp'] + data['Parch']
data.head()

# %%
data.sample(5) #рандомный набор

# %% [markdown]
# А теперь давайте создадим переменную, которая бы нам показывала, что пассажир ехал в одиночку. Такой пассажир путешествовал без родственников. Мы напишем условие с помощью анонимной функции (1, если FamilySize равно 0 и 0 во всех остальных случаях) и применим ее к столбцу FamilySize с помощью метода .apply().

# %%
data['Alone'] = data['FamilySize'].apply(lambda x: 1 if x == 0 else 0)
data.head()

# %%
data[data['Alone'] == 0]

# %% [markdown]
# Функция, которую применяем к столбцу, может быть и посложнее. Давайте из каждого имени пассажира достанем его титул. Сначала потренируемся на одном пассажире.

# %%
data.loc[0]['Name']

# %% [markdown]
# Ок, выбрали имя. Это строка. Давайте подумаем, как достать из нее титул. Вроде бы титул всегда после фамилии. Разобьем строку по пробелу и доставим второй (первый по индексу) элемент.

# %%
data.loc[0]['Name'].split(', ')[1].split('.')[0]

# %% [markdown]
# Ура! Теперь напишем функцию, которая будет забирать титул из имени, а потом применим ее к колонке Name.

# %%
def return_title(full_name):
    return full_name.split(', ')[1].split('.')[0] + '.'

# %% [markdown]
# Теперь сформируем новый столбец family_name из столбца Name с помощью написанной нами функции:

# %%
data['Title'] = data.Name.apply(return_title)

# %%
data.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 244          244         0       3        Maenpaa, Mr. Matti Alexanteri
# 56            56         1       1                    Woolner, Mr. Hugh
# 826          826         0       3                      Flynn, Mr. John
# 803          803         1       1  Carter, Master. William Thornton II
# 377          377         1       3      Landergren, Miss. Aurora Adelia
#
#         Sex   Age  SibSp  Parch             Ticket     Fare    Cabin Embarked  \
# 244    male  22.0      0      0  STON/O 2. 3101275    7.125      NaN        S
# 56     male   NaN      0      0              19947   35.500      C52        S
# 826    male   NaN      0      0             368323    6.950      NaN        Q
# 803    male  11.0      1      2             113760  120.000  B96 B98        S
# 377  female  22.0      0      0             C 7077    7.250      NaN        S
#
#        Title
# 244      Mr.
# 56       Mr.
# 826      Mr.
# 803  Master.
# 377    Miss.

# %% [markdown]
# Кстати, удалить колонку можно так. В нашем анализе мы не будем использовать колонку Ticket, даайте удалим ее.

# %%
del data['Ticket']

# %%
data['Title'].unique()
# Out:
# array(['Mr.', 'Mrs.', 'Miss.', 'Master.', 'Don.', 'Rev.', 'Dr.', 'Mme.',
#        'Ms.', 'Major.', 'Lady.', 'Sir.', 'Mlle.', 'Col.', 'Capt.',
#        'the Countess.', 'Jonkheer.'], dtype=object)

# %%
data['Title'].nunique()
# Out:
# 17

# %% [markdown]
# Полезно посмотреть, какие значения содержатся в столбце. Для категориальных данных можно посчитать частоту встречаемости каждого значения с помошью функции value_counts:

# %%
data['Title'].value_counts()
# Out:
# Title
# Mr.              517
# Miss.            183
# Mrs.             125
# Master.           40
# Dr.                7
# Rev.               6
# Mlle.              2
# Major.             2
# Col.               2
# the Countess.      1
# Capt.              1
# Ms.                1
# Sir.               1
# Lady.              1
# Mme.               1
# Don.               1
# Jonkheer.          1
# Name: count, dtype: int64

# %%
data['Title'].value_counts(normalize=True) # * 100
# Out:
# Title
# Mr.              0.579596
# Miss.            0.205157
# Mrs.             0.140135
# Master.          0.044843
# Dr.              0.007848
# Rev.             0.006726
# Mlle.            0.002242
# Major.           0.002242
# Col.             0.002242
# the Countess.    0.001121
# Capt.            0.001121
# Ms.              0.001121
# Sir.             0.001121
# Lady.            0.001121
# Mme.             0.001121
# Don.             0.001121
# Jonkheer.        0.001121
# Name: proportion, dtype: float64

# %% [markdown]
# Очень много уникальных значений! Обычно это не очень хорошо для статистического анализа, давайте все такие титулы переиминуем в Misc (другие).

# %%
data['Title'] = data['Title'].apply(lambda x: 'Misc' if x not in ['Mr.', 'Miss.', 'Mrs.', 'Master.'] else x)

# %%
data['Title'].value_counts()
# Out:
# Title
# Mr.        517
# Miss.      183
# Mrs.       125
# Master.     40
# Misc        27
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    492
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    645
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# Данные можно сортировать:

# %%
data.sort_values(by=['Age']).head() # сортируем по возрасту, по умолчанию сортирвка по возрастанию
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 804          804         1       3  Thomas, Master. Assad Alexander    male
# 756          756         1       2        Hamalainen, Master. Viljo    male
# 645          645         1       3           Baclini, Miss. Eugenie  female
# 470          470         1       3    Baclini, Miss. Helene Barbara  female
# 79            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked    Title
# 804  0.42      0      1    2625   8.5167   NaN        C  Master.
# 756  0.67      1      1  250649  14.5000   NaN        S  Master.
# 645  0.75      2      1    2666  19.2583   NaN        C    Miss.
# 470  0.75      2      1    2666  19.2583   NaN        C    Miss.
# 79   0.83      0      2  248738  29.0000   NaN        S  Master.

# %%
data.sort_values(by=['Age']).iloc[0]
data.sort_values(by=['Age']).iloc[803]
# Out:
# PassengerId                                452
# Survived                                     0
# Pclass                                       3
# Name           Hagland, Mr. Ingvald Olai Olsen
# Sex                                       male
# Age                                        NaN
# SibSp                                        1
# Parch                                        0
# Ticket                                   65303
# Fare                                   19.9667
# Cabin                                      NaN
# Embarked                                     S
# Title                                      Mr.
# Name: 452, dtype: object

# %%
data.sort_values(by=['Age'], ascending=False).head() # сортируем по возрасту, теперь по убыванию

# %%
data.sort_values(
    by=['Age', 'Fare'],
    ascending=False).head(15)  # сортируем сперва по возрасту (по убыванию),
# потом по стоимости билета  (по убыванию)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 631          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 852          852         0       3                   Svensson, Mr. Johan
# 494          494         0       1               Artagaveytia, Mr. Ramon
# 97            97         0       1             Goldschmidt, Mr. George B
# 117          117         0       3                  Connors, Mr. Patrick
# 746          746         0       1          Crosby, Capt. Edward Gifford
# 673          673         0       2           Mitchell, Mr. Henry Michael
# 34            34         0       2                 Wheadon, Mr. Edward H
# 55            55         0       1        Ostby, Mr. Engelhart Cornelius
# 457          457         0       1             Millet, Mr. Francis Davis
# 281          281         0       3                      Duane, Mr. Frank
# 439          439         0       1                     Fortune, Mr. Mark
# 546          546         0       1          Nicholson, Mr. Arthur Ernest
# 276          276         1       1     Andrews, Miss. Kornelia Theodosia
# 484          484         1       3                Turkula, Mrs. (Hedwig)
#
#         Sex   Age  SibSp  Parch      Ticket      Fare        Cabin Embarked  \
# 631    male  80.0      0      0       27042   30.0000          A23        S
# 852    male  74.0      0      0      347060    7.7750          NaN        S
# 494    male  71.0      0      0    PC 17609   49.5042          NaN        C
# 97     male  71.0      0      0    PC 17754   34.6542           A5        C
# 117    male  70.5      0      0      370369    7.7500          NaN        Q
# 746    male  70.0      1      1   WE/P 5735   71.0000          B22        S
# 673    male  70.0      0      0  C.A. 24580   10.5000          NaN        S
# 34     male  66.0      0      0  C.A. 24579   10.5000          NaN        S
# 55     male  65.0      0      1      113509   61.9792          B30        C
# 457    male  65.0      0      0       13509   26.5500          E38        S
# 281    male  65.0      0      0      336439    7.7500          NaN        Q
# 439    male  64.0      1      4       19950  263.0000  C23 C25 C27        S
# 546    male  64.0      0      0         693   26.0000          NaN        S
# 276  female  63.0      1      0       13502   77.9583           D7        S
# 484  female  63.0      0      0        4134    9.5875          NaN        S
#
#      Title
# 631    Mr.
# 852    Mr.
# 494    Mr.
# 97     Mr.
# 117    Mr.
# 746   Misc
# 673    Mr.
# 34     Mr.
# 55     Mr.
# 457    Mr.
# 281    Mr.
# 439    Mr.
# 546    Mr.
# 276  Miss.
# 484   Mrs.

# %%
data.sort_values(by=['Age', 'Fare'], ascending=[False, True]).head(15)
# сортируем сперва по возрасту (по убыванию),
# потом стоимости билета  (по возрастанию)

# %% [markdown]
# И группировать:

# %%
data.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.663862
# Name: Fare, dtype: float64

# %%
data.groupby('Pclass')[['Fare']].mean() # так просто симпатичней выведет
# Out:
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.663862

# %%
data.groupby('Pclass')[['Fare']].mean().shape
# Out:
# (3, 1)

# %%
data.groupby('Pclass')[['Fare']].mean().index
# Out:
# Index([1, 2, 3], dtype='int64', name='Pclass')

# %%
data.groupby('Pclass')[['Fare']].mean().reset_index()
# Out:
#    Pclass       Fare
# 0       1  84.154687
# 1       2  20.662183
# 2       3  13.663862

# %%
data.groupby('Pclass')['Fare'].min()
# Out:
# Pclass
# 1    0.0
# 2    0.0
# 3    0.0
# Name: Fare, dtype: float64

# %%
data[data['Fare'] == 0]

# %%
data.groupby('Pclass')['Fare'].max()

# %%
data.groupby('Pclass')['Fare'].agg(['min', 'max', 'median', 'mean'])
# Out:
#         min       max   median       mean
# Pclass
# 1       0.0  512.3292  60.2875  84.154687
# 2       0.0   73.5000  14.2500  20.662183
# 3       0.0   69.5500   8.0500  13.663862

# %%
data.groupby('Sex') # разбиение всех объектов на 2 группы по полу - возращает просто сгруппированый датафрейм

# %%
# группируем по полу и считаем для каждого пассажирова разных классов
data.groupby('Sex')['Pclass'].value_counts()
# Out:
# Sex     Pclass
# female  3         145
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: count, dtype: int64

# %%
data.groupby('Sex')['Age'].mean() # средний возраст для пассажиров каждого из полов

# %% [markdown]
# ## И еще чуть-чуть! Работа с пропущенными значениями.

# %% [markdown]
# Если вы помните, то переменная Age содержит пропущенные значения. Давайте посмотрим информацию об этой колонке.

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      26.0
# 4      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 892, dtype: float64

# %%
data[['Age']].info()  

# обратите внимание - двойные скобки. Так pandas нам вернет датафрейм из одной колонки, а не список.
# А метод info() работает только с датафреймом
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     715 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
data.shape
# Out:
# (892, 13)

# %%
type(data['Age'])  # вот так - объект подобный списку (Series)
# Out:
# pandas.core.series.Series

# %%
type(data[['Age']])  # а вот так - датафрейм
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Вернемся к info(). Мы видим, что из 891 наблюдения у нас только 714 ненулевых значений. Значит, у этих пассажиров возраст неизвестен. Ваши идеи, что можно с этим сделать?

# %% [markdown]
# Есть разные варианты того, что делать с пропущенными значениями - от "не делать ничего и выкинуть их" до "давайте предскажем их значения с помощью нейронки". Почитать можно здесь:
#
# https://towardsdatascience.com/6-different-ways-to-compensate-for-missing-values-data-imputation-with-examples-6022d9ca0779
#
# Мы с вами попробуем сделать второй по сложности вариант (после не делать ничего) и заменить их средним значением (средним или медианой). Для категориальных данных можно заполнять пропущенные значения модой.
#
# Пропущенные значения могут быть закодированы по-разному - 0, 'No response', '999'. В итоге мы их всегда хотим привести к объекту NaN (not a number), с которым могут работать методы pandas. В нашем датасете они уже нужного формата. В других случаях, нужно будет отфильтровать значения и привести их к нужному виду.

# %%
print(data.loc[5, 'Age'])
print(type(data.loc[5, 'Age']))
# Out:
# nan
# <class 'numpy.float64'>

# %%
data['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 887    False
# 888    False
# 889     True
# 890    False
# 891    False
# Name: Age, Length: 892, dtype: bool

# %%
data[data['Age'].isnull()].head() 
# выводим значения датафрейма, в которых отсутствует возраст
# Они возращают True методу .isnull()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 5       0      0  330877   8.4583   NaN        Q
# 17      0      0  244373  13.0000   NaN        S
# 19      0      0    2649   7.2250   NaN        C
# 26      0      0    2631   7.2250   NaN        C
# 28      0      0  330959   7.8792   NaN        Q

# %%
data['Age'].median() # вспомним какая у нас медиана
# Out:
# 28.0

# %%
data['Age_Median'] = data['Age'].fillna(data['Age'].median())   #fillna сделает расчет только для полей которые Nan
# сохраняю результат заполнения в новую колонку

# %%
data[data['Age'].isnull()].head(10)  
# смотрим, что произошло с возрастом в новой колонке у тех, у кого он отсутсвовал
# Out:
#     PassengerId  Survived  Pclass  \
# 6             6         0       3
# 18           18         1       2
# 20           20         1       3
# 27           27         0       3
# 29           29         1       3
# 30           30         0       3
# 32           32         1       1
# 33           33         1       3
# 37           37         1       3
# 43           43         0       3
#
#                                               Name     Sex  Age  SibSp  Parch  \
# 6                                 Moran, Mr. James    male  NaN      0      0
# 18                    Williams, Mr. Charles Eugene    male  NaN      0      0
# 20                         Masselmani, Mrs. Fatima  female  NaN      0      0
# 27                         Emir, Mr. Farred Chehab    male  NaN      0      0
# 29                   O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0      0
# 30                             Todoroff, Mr. Lalio    male  NaN      0      0
# 32  Spencer, Mrs. William Augustus (Marie Eugenie)  female  NaN      1      0
# 33                        Glynn, Miss. Mary Agatha  female  NaN      0      0
# 37                                Mamee, Mr. Hanna    male  NaN      0      0
# 43                             Kraeff, Mr. Theodor    male  NaN      0      0
#
#       Ticket      Fare Cabin Embarked  Title  Age_Median
# 6     330877    8.4583   NaN        Q    Mr.        28.0
# 18    244373   13.0000   NaN        S    Mr.        28.0
# 20      2649    7.2250   NaN        C   Mrs.        28.0
# 27      2631    7.2250   NaN        C    Mr.        28.0
# 29    330959    7.8792   NaN        Q  Miss.        28.0
# 30    349216    7.8958   NaN        S    Mr.        28.0
# 32  PC 17569  146.5208   B78        C   Mrs.        28.0
# 33    335677    7.7500   NaN        Q  Miss.        28.0
# 37      2677    7.2292   NaN        C    Mr.        28.0
# 43    349253    7.8958   NaN        C    Mr.        28.0

# %%
data.head() # А у всех остальных - их нормальный возраст.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            3         1       3
# 4            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3                             Heikkinen, Miss. Laina  female  26.0      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  Title  Age_Median
# 0      0         A/5 21171   7.2500   NaN        S    Mr.        22.0
# 1      0          PC 17599  71.2833   C85        C   Mrs.        38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss.        26.0
# 3      0  STON/O2. 3101282   7.9250   NaN        S  Miss.        26.0
# 4      0            113803  53.1000  C123        S   Mrs.        35.0

# %% [markdown]
# Такой метод один из самых топорных, но сойдет для первого знакомства или черновика анализа в серьезном исследовании. Давайте попробуем теперь немного улучшить его. Посмотрим, как отличается медианный возраст для мужчин и женщин.

# %%
data.groupby('Sex')['Age'].median()
# Out:
# Sex
# female    27.0
# male      29.0
# Name: Age, dtype: float64

# %%
data.groupby('Sex')["Age"].transform('median')
# Out:
# 0      29.0
# 1      27.0
# 2      27.0
# 3      27.0
# 4      27.0
#        ...
# 887    29.0
# 888    27.0
# 889    27.0
# 890    29.0
# 891    29.0
# Name: Age, Length: 892, dtype: float64

# %% [markdown]
# Разница два года! Было бы логично в наших данных заполнять недостающие значения по полу.

# %%
data["Age_Median_Sex"] = data["Age"].fillna(data.groupby('Sex')["Age"]\
                                            .transform('median'))

# %%
data[data['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 5             6         0       3               Moran, Mr. James    male  NaN
# 17           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 19           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 26           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 28           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked  Age_Median  Age_Median_Sex
# 5       0      0  330877   8.4583   NaN        Q        28.0            29.0
# 17      0      0  244373  13.0000   NaN        S        28.0            29.0
# 19      0      0    2649   7.2250   NaN        C        28.0            27.0
# 26      0      0    2631   7.2250   NaN        C        28.0            29.0
# 28      0      0  330959   7.8792   NaN        Q        28.0            27.0

# %%
data.head(6) # Опять проверяем, что это все применилось только к нужным людям
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_Median  Age_Median_Sex
# 0      0         A/5 21171   7.2500   NaN        S        22.0            22.0
# 1      0          PC 17599  71.2833   C85        C        38.0            38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        26.0            26.0
# 3      0            113803  53.1000  C123        S        35.0            35.0
# 4      0            373450   8.0500   NaN        S        35.0            35.0
# 5      0            330877   8.4583   NaN        Q        28.0            29.0

# %% [markdown]
# Разберем как работает предыдущий кусок кода

# %%
# эта функция возвращает нам колонку возраст, где все значения заменены медианой по условию пола
# data.groupby('Sex') - группирует наши значения по полу
# ['Age'] - колонка, с которой работаем
# transform('median') - высчитывает медианный возраст для каждого пола и подставляет ее вместо значения

data.groupby('Sex')['Age'].transform('median').head()
# Out:
# 0    29.0
# 1    27.0
# 2    27.0
# 3    27.0
# 4    29.0
# Name: Age, dtype: float64

# %%
data.iloc[5]
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Title                               Mr.
# Age_Median                         35.0
# Name: 5, dtype: object

# %%
# data['Age'] = data['Age'].fillna(data['Age_Median_Sex'])

# %%
data.iloc[5]
# Out:
# PassengerId                      6
# Survived                         0
# Pclass                           3
# Name              Moran, Mr. James
# Sex                           male
# Age                           29.0
# SibSp                            0
# Parch                            0
# Ticket                      330877
# Fare                        8.4583
# Cabin                          NaN
# Embarked                         Q
# Age_Median                    28.0
# Age_Median_Sex                29.0
# Name: 5, dtype: object

# %% [markdown]
# <hr>

# %% [markdown]
# ## Задание
# Заполните осутствующие значения переменной "возраст" на основании титула.

# %%
data[data['Age'].isnull()].head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  Age  \
# 6             6         0       3               Moran, Mr. James    male  NaN
# 18           18         1       2   Williams, Mr. Charles Eugene    male  NaN
# 20           20         1       3        Masselmani, Mrs. Fatima  female  NaN
# 27           27         0       3        Emir, Mr. Farred Chehab    male  NaN
# 29           29         1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked  Title  Age_Median  \
# 6       0      0  330877   8.4583   NaN        Q    Mr.        28.0
# 18      0      0  244373  13.0000   NaN        S    Mr.        28.0
# 20      0      0    2649   7.2250   NaN        C   Mrs.        28.0
# 27      0      0    2631   7.2250   NaN        C    Mr.        28.0
# 29      0      0  330959   7.8792   NaN        Q  Miss.        28.0
#
#     Age_mean_Title
# 6        32.368090
# 18       32.368090
# 20       35.898148
# 27       32.368090
# 29       21.802721

# %%
data['Age_mean_Title'] = data.groupby('Title')['Age'].transform('mean')

# %%
data['Age_mean_Title'] = data['Age'].fillna(data.groupby('Title')['Age'].transform('mean'))

# %%
data.Age.isna().sum()
# Out:
# 177

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  Age_Median  \
# 0        0         A/5 21171   7.2500   NaN        S        22.0
# 1        0          PC 17599  71.2833   C85        C        38.0
# 2        0  STON/O2. 3101282   7.9250   NaN        S        26.0
# 3        0            113803  53.1000  C123        S        35.0
# 4        0            373450   8.0500   NaN        S        35.0
# ..     ...               ...      ...   ...      ...         ...
# 886      0            211536  13.0000   NaN        S        27.0
# 887      0            112053  30.0000   B42        S        19.0
# 888      2        W./C. 6607  23.4500   NaN        S        28.0
# 889      0            111369  30.0000  C148        C        26.0
# 890      0            370376   7.7500   NaN        Q        32.0
#
#      Age_Median_Sex  Title
# 0              22.0    Mr.
# 1              38.0   Mrs.
# 2              26.0  Miss.
# 3              35.0   Mrs.
# 4              35.0    Mr.
# ..              ...    ...
# 886            27.0   Rev.
# 887            19.0  Miss.
# 888            27.0  Miss.
# 889            26.0    Mr.
# 890            32.0    Mr.
#
# [891 rows x 15 columns]

# %%
data.groupby('Title')["Age"].median()
# Out:
# Title
# Master.     3.5
# Misc       44.5
# Miss.      21.0
# Mr.        30.0
# Mrs.       35.0
# Name: Age, dtype: float64

# %%
# TODO
# data["MedianAge"] = 
data["MedianAge"] = data['Age'].fillna(data.groupby('Title')["Age"].transform('median'))
#                                             .transform('median')
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  Age_Median  \
# 0      0         A/5 21171   7.2500   NaN        S        22.0
# 1      0          PC 17599  71.2833   C85        C        38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        26.0
# 3      0            113803  53.1000  C123        S        35.0
# 4      0            373450   8.0500   NaN        S        35.0
# 5      0            330877   8.4583   NaN        Q        28.0
# 6      0             17463  51.8625   E46        S        54.0
# 7      1            349909  21.0750   NaN        S         2.0
# 8      2            347742  11.1333   NaN        S        27.0
# 9      0            237736  30.0708   NaN        C        14.0
#
#    Age_Median_Sex    Title  MedianAge
# 0            22.0      Mr.       22.0
# 1            38.0     Mrs.       38.0
# 2            26.0    Miss.       26.0
# 3            35.0     Mrs.       35.0
# 4            35.0      Mr.       35.0
# 5            29.0      Mr.       30.0
# 6            54.0      Mr.       54.0
# 7             2.0  Master.        2.0
# 8            27.0     Mrs.       27.0
# 9            14.0     Mrs.       14.0

# %% [markdown]
# <hr>

# %% [markdown]
# ### Заполнение по моде для категориальных переменных

# %% [markdown]
# Тоже самое (почти!) работает и для категориальных переменных.

# %%
data[data["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Age_Median  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN        38.0
# 829  female  62.0      0      0  113572  80.0   B28      NaN        62.0
#
#      Age_Median_Sex  Title  MedianAge
# 61             38.0  Miss.       38.0
# 829            62.0   Mrs.       62.0

# %% [markdown]
# Давайте посмотрим, что возвращает нам функция мода - не число, как например median или mean, а список.

# %%
data['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %% [markdown]
# Чтобы передать ее результат методу fillna, нам нужно "вытащить" значение из него (а это мы умеем делать - оно лежит под нулевым индексом).

# %%
data['Embarked'].mode()[0]
# Out:
# 'S'

# %%
# применяем
data["Embarked_Mode"] = data["Embarked"].fillna(data['Embarked'].mode()[0])

# %%
# проверяем
data.loc[61]
# Out:
# PassengerId                        62
# Survived                            1
# Pclass                              1
# Name              Icard, Miss. Amelie
# Sex                            female
# Age                              38.0
# SibSp                               0
# Parch                               0
# Ticket                         113572
# Fare                             80.0
# Cabin                             B28
# Embarked                          NaN
# Age_Median                       38.0
# Age_Median_Sex                   38.0
# Title                           Miss.
# MedianAge                        38.0
# Embarked_Mode                       S
# Name: 61, dtype: object

# %%
data[data["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Age_Median  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN        38.0
# 829  female  62.0      0      0  113572  80.0   B28      NaN        62.0
#
#      Age_Median_Sex  Title  MedianAge Embarked_Mode
# 61             38.0  Miss.       38.0             S
# 829            62.0   Mrs.       62.0             S

# %% [markdown]
# ### Самое важное! Сохраним результаты изменений таблицы

# %%
# data.to_csv('titanic_new.csv', index = False)
data.to_csv('titanic_new.csv')

# %%
df = pd.read_csv('titanic_new.csv')
df.head(6)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            3         1       3
# 4           4            4         1       1
# 5           5            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3                             Heikkinen, Miss. Laina  female  26.0      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title  Age_Median  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr.        22.0
# 1      0          PC 17599  71.2833   C85        C   Mrs.        38.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss.        26.0
# 3      0  STON/O2. 3101282   7.9250   NaN        S  Miss.        26.0
# 4      0            113803  53.1000  C123        S   Mrs.        35.0
# 5      0            373450   8.0500   NaN        S    Mr.        35.0
#
#    Age_mean_Title
# 0            22.0
# 1            38.0
# 2            26.0
# 3            26.0
# 4            35.0
# 5            35.0
